# %% [markdown]
# <center>
#     <b>
#         <big>
#             Exploratory Data analysis of our data on [inaturalist](http://www.inaturalist.org)
#         </big>
#     </b>
# </center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import powerlaw

sns.set_context('notebook')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import folium

# %% [markdown]
# # Data wrangling

# %%
first_dump = pd.read_csv('./inaturalist_dump.csv')
print(first_dump.shape)
first_dump.head(2)
# Out:
# (208, 41)
#       id    observed_on_string observed_on           time_observed_at  \
# 0  56961  March 01, 2012 14:15  2012-03-01  2012-03-01 14:15:00 -0500
# 1  56964  March 01, 2012 14:14  2012-03-01  2012-03-01 14:14:00 -0500
#
#                     time_zone out_of_range  user_id user_login  \
# 0  Eastern Time (US & Canada)        False     1000       muir
# 1  Eastern Time (US & Canada)        False     1000       muir
#
#                   created_at                 updated_at  \
# 0  2012-03-10 19:04:00 -0500  2016-12-19 12:58:08 -0500
# 1  2012-03-10 19:04:01 -0500  2016-12-19 12:56:46 -0500
#
#                         ...                        iconic_taxon_name taxon_id  \
# 0                       ...                                 Mammalia  44181.0
# 1                       ...                                 Mammalia  43485.0
#
#   field:how do you rate the level of hygiene of the market place  \
# 0                                                NaN
# 1                                                NaN
#
#   field:what is the common name of the product in english  \
# 0                                                NaN
# 1                                                NaN
#
#   field:what is the geographical origin of the product: local, national or international   \
# 0                                                NaN
# 1                                                NaN
#
#   field:what is the local name of the product  \
# 0                                         NaN
# 1                                         NaN
#
#   field:what is the name of the food market you are visiting  \
# 0                                                NaN
# 1                                                NaN
#
#    field:what is the nutritional value and/or health benefits (health claims) of the product  \
# 0                                                NaN
# 1                                                NaN
#
#    field:what is the price of the product  \
# 0                                     NaN
# 1                                     NaN
#
#   field:what is the scientific name of the product
# 0                                              NaN
# 1                                              NaN
#
# [2 rows x 41 columns]

# %%
# first_dump.scientific_name.unique()

# %%
first_dump.notnull().sum()
# Out:
# id                                                                                           208
# observed_on_string                                                                           179
# observed_on                                                                                  178
# time_observed_at                                                                              16
# time_zone                                                                                    208
# out_of_range                                                                                  14
# user_id                                                                                      208
# user_login                                                                                   208
# created_at                                                                                   208
# updated_at                                                                                   208
# quality_grade                                                                                208
# license                                                                                      197
# url                                                                                          208
# image_url                                                                                    208
# tag_list                                                                                      11
# description                                                                                  184
# id_please                                                                                    208
# num_identification_agreements                                                                208
# num_identification_disagreements                                                             208
# captive_cultivated                                                                           208
# oauth_application_id                                                                           2
# place_guess                                                                                  206
# latitude                                                                                     207
# longitude                                                                                    207
# positional_accuracy                                                                           97
# geoprivacy                                                                                     0
# positioning_method                                                                             2
# positioning_device                                                                            13
# species_guess                                                                                206
# scientific_name                                                                              204
# common_name                                                                                  190
# iconic_taxon_name                                                                            205
# taxon_id                                                                                     205
# field:how do you rate the level of hygiene of the market place                                 0
# field:what is the common name of the product in english                                        0
# field:what is the geographical origin of the product: local, national or international         0
# field:what is the local name of the product                                                    0
# field:what is the name of the food market you are visiting                                     0
# field:what is the nutritional value and/or health benefits (health claims) of the product      0
# field:what is the price of the product                                                         0
# field:what is the scientific name of the product                                               0
# dtype: int64

# %%
first_dump.dtypes
# Out:
# id                                                                                             int64
# observed_on_string                                                                            object
# observed_on                                                                                   object
# time_observed_at                                                                              object
# time_zone                                                                                     object
# out_of_range                                                                                  object
# user_id                                                                                        int64
# user_login                                                                                    object
# created_at                                                                                    object
# updated_at                                                                                    object
# quality_grade                                                                                 object
# license                                                                                       object
# url                                                                                           object
# image_url                                                                                     object
# tag_list                                                                                      object
# description                                                                                   object
# id_please                                                                                       bool
# num_identification_agreements                                                                  int64
# num_identification_disagreements                                                               int64
# captive_cultivated                                                                              bool
# oauth_application_id                                                                         float64
# place_guess                                                                                   object
# latitude                                                                                     float64
# longitude                                                                                    float64
# positional_accuracy                                                                          float64
# geoprivacy                                                                                   float64
# positioning_method                                                                            object
# positioning_device                                                                            object
# species_guess                                                                                 object
# scientific_name                                                                               object
# common_name                                                                                   object
# iconic_taxon_name                                                                             object
# taxon_id                                                                                     float64
# field:how do you rate the level of hygiene of the market place                               float64
# field:what is the common name of the product in english                                      float64
# field:what is the geographical origin of the product: local, national or international       float64
# field:what is the local name of the product                                                  float64
# field:what is the name of the food market you are visiting                                   float64
# field:what is the nutritional value and/or health benefits (health claims) of the product    float64
# field:what is the price of the product                                                       float64
# field:what is the scientific name of the product                                             float64
# dtype: object

# %% [markdown]
# ###   json exporting   of useful features

# %%
website_dataset = first_dump[['id','user_login','observed_on',
                              'image_url','latitude',
                             'longitude','common_name']]

website_dataset['market_name'] = np.nan
website_dataset['geographical_origin'] = np.nan
website_dataset['health_facts'] = np.nan
website_dataset['usage'] = np.nan

website_dataset.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        id user_login observed_on  \
# 0   56961       muir  2012-03-01
# 1   56964       muir  2012-03-01
# 2   77056     akrohn  2010-10-17
# 3  456868      tonyg  2013-06-05
# 4  481944      tonyg  2013-06-21
#
#                                            image_url   latitude   longitude  \
# 0  https://static.inaturalist.org/photos/88639/me...   1.854370   10.052250
# 1  https://static.inaturalist.org/photos/88646/me...   1.854370   10.052250
# 2  https://static.inaturalist.org/photos/114209/m...   5.769016   -7.179026
# 3  https://static.inaturalist.org/photos/576493/m...  16.387541  121.112396
# 4  https://static.inaturalist.org/photos/609362/m...  16.387541  121.112396
#
#                       common_name  market_name  geographical_origin  \
# 0  African Brush-tailed Porcupine          NaN                  NaN
# 1              Putty-nosed Monkey          NaN                  NaN
# 2                Green Bush Viper          NaN                  NaN
# 3                             NaN          NaN                  NaN
# 4                   Mole Crickets          NaN                  NaN
#
#    health_facts  usage
# 0           NaN    NaN
# 1           NaN    NaN
# 2           NaN    NaN
# 3           NaN    NaN
# 4           NaN    NaN

# %%
pd.DataFrame.to_json(website_dataset.transpose(),'./inaturalist_dump_trial.json')

# %% [markdown]
# # Create markets map
#
# (here is the [folium documentation](https://github.com/python-visualization/folium))

# %%
markets_map = folium.Map(location=[0,0], tiles='Stamen Terrain',zoom_start=2)

# folium.ClickForMarker(popup='Waypoint').add_to(markets_map)

for row in first_dump.itertuples():

    def get_frame(url,width,height):

        html = """ 
                <!doctype html>
            <html>
            <iframe id="myIFrame" width="{}" height="{}" src={}""".format(width,height,url) + """ frameborder="0"></iframe>
            <script type="text/javascript">
            var resizeIFrame = function(event) {
                var loc = document.location;
                if (event.origin != loc.protocol + '//' + loc.host) return;

                var myIFrame = document.getElementById('myIFrame');
                if (myIFrame) {
                    myIFrame.style.height = event.data.h + "px";
                    myIFrame.style.width  = event.data.w + "px";
                }
            };
        if (window.addEventListener) {
            window.addEventListener("message", resizeIFrame, false);
        } else if (window.attachEvent) {
            window.attachEvent("onmessage", resizeIFrame);
        }
        </script>
        </html>"""

    popup = get_frame(row.image_url + '.html',100,200)

    #     iframe = folium.element.IFrame(html=row.image_url, width=500, height=300)
    popup = folium.Popup(html=popup, max_width=2650)
        
    folium.Marker(
        location=[row.latitude, row.longitude],
        popup=my_html).add_to(markets_map)
#         popup=str(row.common_name)).add_to(markets_map)

markets_map.save('markets_map.html')

markets_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# # Descriptive Analysis

# %%
first_dump.columns
# Out:
# Index(['id', 'observed_on_string', 'observed_on', 'time_observed_at',
#        'time_zone', 'out_of_range', 'user_id', 'user_login', 'created_at',
#        'updated_at', 'quality_grade', 'license', 'url', 'image_url',
#        'tag_list', 'description', 'id_please', 'num_identification_agreements',
#        'num_identification_disagreements', 'captive_cultivated',
#        'oauth_application_id', 'place_guess', 'latitude', 'longitude',
#        'positional_accuracy', 'geoprivacy', 'positioning_method',
#        'positioning_device', 'species_guess', 'scientific_name', 'common_name',
#        'iconic_taxon_name', 'taxon_id',
#        'field:how do you rate the level of hygiene of the market place',
#        'field:what is the common name of the product in english',
#        'field:what is the geographical origin of the product: local, national or international ',
#        'field:what is the local name of the product',
#        'field:what is the name of the food market you are visiting',
#        'field:what is the nutritional value and/or health benefits (health claims) of the product',
#        'field:what is the price of the product',
#        'field:what is the scientific name of the product'],
#       dtype='object')

# %%
sns.countplot(y=first_dump.iconic_taxon_name);

# %%
sns.countplot(first_dump.license);

# %%
sns.countplot(first_dump.quality_grade);

# %%
sns.countplot(first_dump.captive_cultivated);

# %%
sns.countplot(first_dump.positioning_device);

# %%
sns.countplot(first_dump.positioning_method);

# %%
sns.distplot(first_dump.positional_accuracy.dropna(),kde=False)
plt.yscale('log');
